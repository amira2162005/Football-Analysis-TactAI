# %%
# !nvidia-smi
# Out:
# Sun May 11 02:12:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os

print(os.listdir("/content/drive/MyDrive/Data/jersey_number"))
# Out:
# ['valid', 'README.roboflow.txt', 'data.yaml', 'README.dataset.txt', 'train', 'test']

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 875.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Load model YOLOv8 pre-trained
model = YOLO("yolo11m.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 38.8M/38.8M [00:00<00:00, 108MB/s]

# %%
model.train(data="/content/drive/MyDrive/Data/jersey_number/data.yaml", epochs=20, imgsz=640, device=[0])
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(split="test")
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,107,132 parameters, 0 gradients, 68.1 GFLOPs
# val: Fast image access ✅ (ping: 0.8±0.4 ms, read: 0.0±0.0 MB/s, size: 1.3 KB)
# val: Scanning /content/drive/MyDrive/Data/jersey_number/test/labels.cache... 1436 images, 4 backgrounds, 0 corrupt: 100%|██████████| 1436/1436 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 90/90 [00:54<00:00,  1.65it/s]
#                    all       1436       1437      0.953      0.895      0.953        0.8
#                      0          1          1          1          0      0.142      0.114
#                      1         25         25      0.766      0.787      0.758      0.458
#                     10         67         67       0.97      0.957      0.962      0.704
# ...

# %%
import cv2
from matplotlib import pyplot as plt

model_path = '/content/runs/detect/train/weights/best.pt'
model = YOLO(model_path)

image_path = '/content/garnagoat.png'

image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

results = model(image_rgb)
annotated_image = results[0].plot()

# Menampilkan hasil
plt.figure(figsize=(10, 8))
plt.imshow(annotated_image)
plt.axis('off')
plt.title("Hasil Prediksi")
plt.savefig('results.jpg')
plt.show()
# Out:
# 0: 448x640 1 19, 1 49, 29.2ms
# Speed: 2.1ms preprocess, 29.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
import shutil
import os

folder_path = "/content/runs"
shutil.make_archive("hasil", 'zip', folder_path)

print("Download ZIP file: hasil.zip")
# Out:
# Download ZIP file: hasil.zip
